# %% [markdown]
# This notebook is inspired by the notebook Parkinson_Telemonitoring found here https://github.com/mrpintime/Parkinsons-Telemonitoring/blob/main/Parkinsons_Telemonitoring.ipynb.
#
# In this notebook we use PCA components as features to try and improve the predictions.

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# import data
X_train_original = pd.read_pickle('data/X_train_scaled.pkl')
X_test_original = pd.read_pickle('data/X_test_scaled.pkl')
y_train_common = pd.read_pickle('data/y_train_common.pkl')
y_train_motor = pd.read_pickle('data/y_train_motor.pkl')
y_train_total = pd.read_pickle('data/y_train_total.pkl')
y_test_common = pd.read_pickle('data/y_test_common.pkl')
y_test_motor = pd.read_pickle('data/y_test_motor.pkl')
y_test_total = pd.read_pickle('data/y_test_total.pkl')

# %%
X_train_original.corr().style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_c4e5e_row0_col0, #T_c4e5e_row1_col1, #T_c4e5e_row2_col2, #T_c4e5e_row3_col3, #T_c4e5e_row3_col5, #T_c4e5e_row4_col4, #T_c4e5e_row5_col3, #T_c4e5e_row5_col5, #T_c4e5e_row6_col6, #T_c4e5e_row7_col7, #T_c4e5e_row7_col10, #T_c4e5e_row8_col8, #T_c4e5e_row9_col9, #T_c4e5e_row10_col7, #T_c4e5e_row10_col10, #T_c4e5e_row11_col11, #T_c4e5e_row12_col12, #T_c4e5e_row13_col13, #T_c4e5e_row14_col14, #T_c4e5e_row15_col15, #T_c4e5e_row16_col16, #T_c4e5e_row17_col17, #T_c4e5e_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c4e5e_row0_col1, #T_c4e5e_row1_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c4e5e_row0_col2, #T_c4e5e_row2_col0, #T_c4e5e_row13_col18, #T_c4e5e_row18_col13 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_c4e5e_row0_col3, #T_c4e5e_row0_col5, #T_c4e5e_row3_col0, #T_c4e5e_row5_col0, #T_c4e5e_row11_col13, #T_c4e5e_row13_col11, #T_c4e5e_row15_col16, #T_c4e5e_row16_col15 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_c4e5e_row0_col4, #T_c4e5e_row4_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c4e5e_row0_col6, #T_c4e5e_row0_col8, #T_c4e5e_row6_col0, #T_c4e5e_row6_col16, #T_c4e5e_row7_col16, #T_c4e5e_row8_col0, #T_c4e5e_row10_col16, #T_c4e5e_row16_col6, #T_c4e5e_row16_col7, #T_c4e5e_row16_col10 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_c4e5e_row0_col7, #T_c4e5e_row0_col10, #T_c4e5e_row0_col17, #T_c4e5e_row7_col0, #T_c4e5e_row8_col16, #T_c4e5e_row9_col16, #T_c4e5e_row10_col0, #T_c4e5e_row12_col16, #T_c4e5e_row16_col8, #T_c4e5e_row16_col9, #T_c4e5e_row16_col12, #T_c4e5e_row17_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_c4e5e_row0_col9, #T_c4e5e_row0_col13, #T_c4e5e_row9_col0, #T_c4e5e_row13_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_c4e5e_row0_col11, #T_c4e5e_row0_col18, #T_c4e5e_row11_col0, #T_c4e5e_row11_col15, #T_c4e5e_row15_col11, #T_c4e5e_row18_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_c4e5e_row0_col12, #T_c4e5e_row12_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_c4e5e_row0_col14, #T_c4e5e_row14_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c4e5e_row0_col15, #T_c4e5e_row15_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_c4e5e_row0_col16, #T_c4e5e_row16_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_c4e5e_row1_col2, #T_c4e5e_row2_col1, #T_c4e5e_row7_col9, #T_c4e5e_row9_col7, #T_c4e5e_row9_col10, #T_c4e5e_row10_col9 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_c4e5e_row1_col3, #T_c4e5e_row1_col5, #T_c4e5e_row3_col1, #T_c4e5e_row5_col1, #T_c4e5e_row7_col17, #T_c4e5e_row10_col17, #T_c4e5e_row17_col7, #T_c4e5e_row17_col10 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_c4e5e_row1_col4, #T_c4e5e_row4_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_c4e5e_row1_col6, #T_c4e5e_row6_col1, #T_c4e5e_row6_col14, #T_c4e5e_row14_col6 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_c4e5e_row1_col7, #T_c4e5e_row1_col10, #T_c4e5e_row2_col17, #T_c4e5e_row7_col1, #T_c4e5e_row10_col1, #T_c4e5e_row17_col2 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_c4e5e_row1_col8, #T_c4e5e_row1_col9, #T_c4e5e_row8_col1, #T_c4e5e_row9_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_c4e5e_row1_col11, #T_c4e5e_row4_col6, #T_c4e5e_row6_col4, #T_c4e5e_row11_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_c4e5e_row1_col12, #T_c4e5e_row3_col17, #T_c4e5e_row5_col17, #T_c4e5e_row11_col14, #T_c4e5e_row12_col1, #T_c4e5e_row14_col11, #T_c4e5e_row17_col3, #T_c4e5e_row17_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_c4e5e_row1_col13, #T_c4e5e_row9_col12, #T_c4e5e_row11_col12, #T_c4e5e_row12_col9, #T_c4e5e_row12_col11, #T_c4e5e_row13_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_c4e5e_row1_col14, #T_c4e5e_row2_col3, #T_c4e5e_row2_col5, #T_c4e5e_row3_col2, #T_c4e5e_row5_col2, #T_c4e5e_row14_col1 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_c4e5e_row1_col15, #T_c4e5e_row4_col15, #T_c4e5e_row15_col1, #T_c4e5e_row15_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_c4e5e_row1_col16, #T_c4e5e_row11_col16, #T_c4e5e_row13_col16, #T_c4e5e_row14_col16, #T_c4e5e_row16_col1, #T_c4e5e_row16_col11, #T_c4e5e_row16_col13, #T_c4e5e_row16_col14 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c4e5e_row1_col17, #T_c4e5e_row4_col7, #T_c4e5e_row4_col8, #T_c4e5e_row4_col10, #T_c4e5e_row7_col4, #T_c4e5e_row8_col4, #T_c4e5e_row10_col4, #T_c4e5e_row14_col17, #T_c4e5e_row17_col1, #T_c4e5e_row17_col14 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_c4e5e_row1_col18, #T_c4e5e_row18_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c4e5e_row2_col4, #T_c4e5e_row4_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_c4e5e_row2_col6, #T_c4e5e_row3_col8, #T_c4e5e_row5_col8, #T_c4e5e_row6_col2, #T_c4e5e_row7_col14, #T_c4e5e_row8_col3, #T_c4e5e_row8_col5, #T_c4e5e_row10_col14, #T_c4e5e_row14_col7, #T_c4e5e_row14_col10 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_c4e5e_row2_col7, #T_c4e5e_row2_col10, #T_c4e5e_row3_col12, #T_c4e5e_row3_col13, #T_c4e5e_row5_col12, #T_c4e5e_row5_col13, #T_c4e5e_row6_col12, #T_c4e5e_row7_col2, #T_c4e5e_row10_col2, #T_c4e5e_row12_col3, #T_c4e5e_row12_col5, #T_c4e5e_row12_col6, #T_c4e5e_row13_col3, #T_c4e5e_row13_col5 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_c4e5e_row2_col8, #T_c4e5e_row3_col9, #T_c4e5e_row4_col13, #T_c4e5e_row5_col9, #T_c4e5e_row8_col2, #T_c4e5e_row9_col3, #T_c4e5e_row9_col5, #T_c4e5e_row13_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_c4e5e_row2_col9, #T_c4e5e_row2_col13, #T_c4e5e_row9_col2, #T_c4e5e_row13_col2 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_c4e5e_row2_col11, #T_c4e5e_row3_col11, #T_c4e5e_row4_col9, #T_c4e5e_row5_col11, #T_c4e5e_row9_col4, #T_c4e5e_row9_col14, #T_c4e5e_row11_col2, #T_c4e5e_row11_col3, #T_c4e5e_row11_col5, #T_c4e5e_row14_col9 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_c4e5e_row2_col12, #T_c4e5e_row12_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_c4e5e_row2_col14, #T_c4e5e_row14_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_c4e5e_row2_col15, #T_c4e5e_row15_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_c4e5e_row2_col16, #T_c4e5e_row16_col2, #T_c4e5e_row16_col17, #T_c4e5e_row17_col16 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_c4e5e_row2_col18, #T_c4e5e_row18_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c4e5e_row3_col4, #T_c4e5e_row4_col3, #T_c4e5e_row4_col5, #T_c4e5e_row5_col4, #T_c4e5e_row6_col9, #T_c4e5e_row9_col6, #T_c4e5e_row9_col17, #T_c4e5e_row17_col9 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_c4e5e_row3_col6, #T_c4e5e_row3_col7, #T_c4e5e_row3_col10, #T_c4e5e_row5_col6, #T_c4e5e_row5_col7, #T_c4e5e_row5_col10, #T_c4e5e_row6_col3, #T_c4e5e_row6_col5, #T_c4e5e_row7_col3, #T_c4e5e_row7_col5, #T_c4e5e_row10_col3, #T_c4e5e_row10_col5 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_c4e5e_row3_col14, #T_c4e5e_row5_col14, #T_c4e5e_row14_col3, #T_c4e5e_row14_col5 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_c4e5e_row3_col15, #T_c4e5e_row5_col15, #T_c4e5e_row15_col3, #T_c4e5e_row15_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_c4e5e_row3_col16, #T_c4e5e_row4_col16, #T_c4e5e_row5_col16, #T_c4e5e_row16_col3, #T_c4e5e_row16_col4, #T_c4e5e_row16_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c4e5e_row3_col18, #T_c4e5e_row5_col18, #T_c4e5e_row18_col3, #T_c4e5e_row18_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_c4e5e_row4_col11, #T_c4e5e_row4_col17, #T_c4e5e_row11_col4, #T_c4e5e_row17_col4 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_c4e5e_row4_col12, #T_c4e5e_row8_col14, #T_c4e5e_row12_col4, #T_c4e5e_row14_col8 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_c4e5e_row4_col14, #T_c4e5e_row14_col4 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_c4e5e_row4_col18, #T_c4e5e_row18_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c4e5e_row6_col7, #T

# %% [markdown]
# We notice that:
# - all Jitter columns are highly correlated with each other.
# - all Shimmer columns are highly correlated with each other.
# - all HNR columns are highly correlated with each other.
#
# We can remove highly correlated features (> 90)

# %%
def remove_high_correlation_features(X_train, threshold=0.9):
    corr_matrix = X_train.corr().abs()
    upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]
    return X_train.drop(columns=to_drop), to_drop

X_train, dropped_features = remove_high_correlation_features(X_train_original)
X_test = X_test_original.drop(columns=dropped_features)

# %%
X_train.columns
# Out:
# Index(['sex', 'Jitter(%)', 'Jitter(Abs)', 'Shimmer', 'NHR', 'RPDE', 'DFA',
#        'PPE', 'age', 'test_time', 'HNR'],
#       dtype='object')

# %% [markdown]
# We removed the highly correlated columns. Now we check the correlation with the target variable.

# %%
def plot_correlation_with_target(X_train, y_train, target_name):
    correlation = X_train.corrwith(y_train)
    plt.figure(figsize=(10, 6))
    correlation.plot(kind='bar')
    plt.title(f'Correlation with {target_name}')
    plt.xlabel('Features')
    plt.ylabel('Correlation Coefficient')
    plt.show()

plot_correlation_with_target(X_train, y_train_motor, 'y_train_motor')

# %% [markdown]
# Age and HNR are the most correlated features with y_train_motor.

# %%
def plot_feature_distributions(X_train):
    skewness = X_train.skew()
    print("Skewness:\n", skewness.sort_values(ascending=False))

    plt.figure(figsize=(20, 15))
    for i, column in enumerate(X_train.columns):
        plt.subplot(5, 4, i + 1)
        plt.hist(X_train[column], bins=30, alpha=0.7)
        plt.title(column)
        plt.xlabel('Value')
        plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

plot_feature_distributions(X_train)
# Out:
# Skewness:
#  NHR            6.454374
# Shimmer        2.768091
# Jitter(Abs)    1.484635
# Jitter(%)      1.338358
# sex            0.766406
# PPE            0.655141
# DFA            0.136657
# test_time      0.084418
# RPDE          -0.136813
# age           -0.143822
# HNR           -0.178031
# dtype: float64

# %% [markdown]
# We see that there are some features that are skewed so we apply Yeo-Johnson transformation to make the data less skewed.

# %%
# apply power transformation to features with skewness > 1
def apply_power_transformer(X_train, X_test):
    pt = PowerTransformer()
    X_train_transformed = pt.fit_transform(X_train)
    X_test_transformed = pt.transform(X_test)
    return pd.DataFrame(X_train_transformed, columns=X_train.columns), pd.DataFrame(X_test_transformed, columns=X_test.columns)

X_train_transformed, X_test_transformed = apply_power_transformer(X_train, X_test)

# %%
plot_feature_distributions(X_train_transformed)
# Out:
# Skewness:
#  sex            0.766406
# NHR            0.314490
# Jitter(Abs)    0.164414
# Shimmer        0.155928
# Jitter(%)      0.117930
# HNR            0.030201
# DFA            0.014942
# PPE            0.012245
# RPDE          -0.024223
# test_time     -0.032254
# age           -0.084911
# dtype: float64

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# We try PCA to reduce the dimensionality of the data

# %%
pca = PCA(n_components=0.99)
pca.fit(X_train_transformed)

plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o', ls='--', color='blue')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance')
plt.grid()
plt.show()

# %% [markdown]
# After 5 components we can explain 99% of the variance. We use 5 components for PCA.

# %%
pca = PCA(5)
X_train_pca = pca.fit_transform(X_train_transformed)
X_test_pca = pca.transform(X_test_transformed)

X_train_pca = pd.DataFrame(X_train_pca, columns=[f'PC{i+1}' for i in range(X_train_pca.shape[1])])
X_test_pca = pd.DataFrame(X_test_pca, columns=[f'PC{i+1}' for i in range(X_test_pca.shape[1])])

# %%
sns.pairplot(X_train_pca, diag_kind='kde', markers='o')

# %% [markdown]
# We see some clustering in the PCA space, which indicates that the features are not completely independent. This is expected as the original features were correlated. However, PCA has reduced the dimensionality while retaining most of the variance in the data.

# %%
X_train_pca.corr().style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_663b1_row0_col0, #T_663b1_row1_col1, #T_663b1_row2_col2, #T_663b1_row3_col3, #T_663b1_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_663b1_row0_col1, #T_663b1_row0_col2, #T_663b1_row0_col3, #T_663b1_row0_col4, #T_663b1_row1_col0, #T_663b1_row1_col2, #T_663b1_row1_col3, #T_663b1_row1_col4, #T_663b1_row2_col0, #T_663b1_row2_col1, #T_663b1_row2_col3, #T_663b1_row2_col4, #T_663b1_row3_col0, #T_663b1_row3_col1, #T_663b1_row3_col2, #T_663b1_row3_col4, #T_663b1_row4_col0, #T_663b1_row4_col1, #T_663b1_row4_col2, #T_663b1_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_663b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_663b1_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_663b1_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_663b1_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_663b1_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_663b1_level0_col4" class="col_heading level0 col4" >PC5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_663b1_level0_row0" class="row_heading level0 row0" >PC1</th>
#       <td id="T_663b1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_663b1_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_663b1_row0_col2" class="data row0 col2" >-0.000000</td>
#       <td id="T_663b1_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_663b1_row0_col4" class="data row0 col4" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_663b1_level0_row1" class="row_heading level0 row1" >PC2</th>
#       <td id="T_663b1_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_663b1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_663b1_row1_col2" class="data row1 col2" >-0.000000</td>
#       <td id="T_663b1_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_663b1_row1_col4" class="data row1 col4" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_663b1_level0_row2" class="row_heading level0 row2" >PC3</th>
#       <td id="T_663b1_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_663b1_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_663b1_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_663b1_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_663b1_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_663b1_level0_row3" class="row_heading level0 row3" >PC4</th>
#       <td id="T_663b1_row3_col0" class="data row3 col0" >-0.000000</td>
#       <td id="T_663b1_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_663b1_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_663b1_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_663b1_row3_col4" class="data row3 col4" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_663b1_level0_row4" class="row_heading level0 row4" >PC5</th>
#       <td id="T_663b1_row4_col0" class="data row4 col0" >-0.000000</td>
#       <td id="T_663b1_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_663b1_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_663b1_row4_col3" class="data row4 col3" >-0.000000</td>
#       <td id="T_663b1_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We overcome the multicollinearity problem by using PCA. The PCA components are uncorrelated and can be used as features in the model.

# %%
X_train_pca.skew().sort_values(ascending=False)
# Out:
# PC3    0.723068
# PC5    0.015906
# PC4   -0.029362
# PC1   -0.058567
# PC2   -0.086011
# dtype: float64

# %% [markdown]
# The distribution of the PCA components is not normal, but it is not highly skewed. The skewness values are all below 1, which indicates that the distribution is relatively symmetric.

# %%
plot_correlation_with_target(X_train_pca, y_train_motor, 'y_train_motor')

# %%
pca_corr = np.corrcoef(X_train_transformed.T, X_train_pca.T)

feature_names = list(X_train_transformed.columns)

n_components = pca.n_components_
all_ticks = feature_names + [f'PC{i+1}' for i in range(n_components)]

plt.figure(figsize=(12, 8))
import seaborn as sns
sns.heatmap(pca_corr, annot=True, fmt=".2f", cmap='coolwarm', xticklabels=all_ticks, yticklabels=all_ticks)
plt.title('PCA Correlation with Original Features')
plt.xlabel('Original Features and PCA Components')
plt.ylabel('Original Features and PCA Components')
plt.show()

# %% [markdown]
# This shows the correlation between the original features and the PCA components.

# %%
# we combine PCA features with original features
X_train_combined = pd.concat([X_train_transformed, X_train_pca], axis=1)
X_test_combined = pd.concat([X_test_transformed, X_test_pca], axis=1)

# %%
# check performance with linear regression
lr = LinearRegression()
lr.fit(X_train_combined, y_train_motor)
y_train_pred = lr.predict(X_train_combined)
y_test_pred = lr.predict(X_test_combined)

def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    return mae, mse, rmse, r2

mae_train, mse_train, rmse_train, r2_train = evaluate_model(y_train_motor, y_train_pred)
mae_test, mse_test, rmse_test, r2_test = evaluate_model(y_test_motor, y_test_pred)

print(f"Train MAE: {mae_train}, Train MSE: {mse_train}, Train RMSE: {rmse_train}, Train R2: {r2_train}")
print(f"Test MAE: {mae_test}, Test MSE: {mse_test}, Test RMSE: {rmse_test}, Test R2: {r2_test}")
# Out:
# Train MAE: 6.469939344400656, Train MSE: 58.0509708177808, Train RMSE: 7.619118769108459, Train R2: 0.21662823149622024
# Test MAE: 6.800813826672534, Test MSE: 56.04118772113351, Test RMSE: 7.486066238094177, Test R2: -0.743840883567114

# %%
# check performance with Random Forest
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train_combined, y_train_motor)
y_train_pred_rf = rf.predict(X_train_combined)
y_test_pred_rf = rf.predict(X_test_combined)

mae_train_rf, mse_train_rf, rmse_train_rf, r2_train_rf = evaluate_model(y_train_motor, y_train_pred_rf)
mae_test_rf, mse_test_rf, rmse_test_rf, r2_test_rf = evaluate_model(y_test_motor, y_test_pred_rf)

print(f"Random Forest Train MAE: {mae_train_rf}, Train MSE: {mse_train_rf}, Train RMSE: {rmse_train_rf}, Train R2: {r2_train_rf}")
print(f"Random Forest Test MAE: {mae_test_rf}, Test MSE: {mse_test_rf}, Test RMSE: {rmse_test_rf}, Test R2: {r2_test_rf}")
# Out:
# Random Forest Train MAE: 0.22281657768001883, Train MSE: 0.2519135874915124, Train RMSE: 0.5019099396221521, Train R2: 0.9966005393232302
# Random Forest Test MAE: 7.461065197217676, Test MSE: 82.8720679237288, Test RMSE: 9.10340968669041, Test R2: -1.5787408516442145

# %% [markdown]
# Adding PCA as features didn't improve the model performance.
